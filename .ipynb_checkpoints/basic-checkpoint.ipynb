# %% [markdown]
# # ipyniivue — Minimal demo
#
# This notebook demonstrates the minimal usage of `NiiVue` with a single local NIfTI file.

# %%
from ipyniivue import NiiVue
nv = NiiVue()
nv.load_volumes([{'path': './images/mni152.nii.gz'}])
nv
# Out:
# NiiVue(draw_lut=None, graph=<ipyniivue.traits.Graph object at 0x10a55dfd0>, height=300, opts=<ipyniivue.config…
