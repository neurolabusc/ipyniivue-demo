# %% [markdown]
# # Meshes
#
# This is the minimal script to load a mesh.

# %%
from ipyniivue import NiiVue

nv = NiiVue()
nv.load_meshes([{"path": "./images/BrainMesh_ICBM152.lh.mz3", "rgba255": [192, 222, 255, 255]}])
nv
# Out:
# NiiVue(draw_lut=None, graph=<ipyniivue.traits.Graph object at 0x1104d9a30>, height=300, meshes=[Mesh(name='Bra…
